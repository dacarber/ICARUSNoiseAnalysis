# %%
from test_pulse_utilities import average_pulse, average_waveform, compare_average_pulse, plot_single_test_waveform, plot_average_waveform_artdaq, plot_average_pulse_artdaq, fit_bessel,fit_zero_pole,fit_milind,list_bessel_fit, plot_diff_waveform_artdaq
import numpy as np
path = '/Users/danielcarber/Documents/ICARUS/Noise Analysis/TPC_Noise_repo/'
fragment_ew08 = 4626 # EW08
fragment_ew10 = 4630 # EW10

# %%
path_artdaq = '/Users/danielcarber/Documents/ICARUS/Noise Analysis/TPC_Noise_repo/'
plot_average_waveform_artdaq(path_artdaq, 10404, 'Average Test Pulse', 482, 50)

# %%
path_artdaq = '/Users/danielcarber/Documents/ICARUS/Noise Analysis/TPC_Noise_repo/'
plot_average_waveform_artdaq(path_artdaq, 10404, 'Average Test Pulse', 450, 1600)

# %%
path_artdaq = '/Users/danielcarber/Documents/ICARUS/Noise Analysis/TPC_Noise_repo/'
plot_diff_waveform_artdaq(path_artdaq, 10404, 'Difference between channel 450,482', 450,482, 50)

# %%
fit_milind(path_artdaq, 10307, 'Milind Fit Run 10307 Channel 32', 32, 1600,cross_talk =False)
# Out:
# 75
# [ 0.69966531  1.0439045  64.73784969  1.71816731] [[ 4.21117656e-04  2.93090344e-04 -5.92152409e-02  3.61451022e-04]
#  [ 2.93090344e-04  7.22466505e-04 -9.21137911e-02  7.02424154e-04]
#  [-5.92152409e-02 -9.21137911e-02  1.51506334e+01 -1.04855048e-01]
#  [ 3.61451022e-04  7.02424154e-04 -1.04855048e-01  7.59904132e-04]]
# [0.02052115 0.02687874 3.89238146 0.02756636]
# Fit statistics
# Chi^2:  -577117217728903.8
# Fit Peaks [ 5.9 30.2]
# Fit Widths of peak in fit  [8.04787763 5.72060319]
# Integral of fit from -100 to 2000  (10879.043719470661, 1.5079844395415876e-06)
# Peak value 1356.0173343253484
# Data statistics
# Data Peaks [  2  15  32  37  45  57  75 100 136 145]
# Data Widths of peak  [80.47877632 57.2060319 ]
# Data peak value 1378.9928343949045

# %%
from sympy.integrals.transforms import inverse_laplace_transform
from sympy import exp, Symbol, sin
from sympy.abc import s, t

# %%
fit_bessel(path_artdaq, 10307, 'Bessel Fit Run 10307 Crate EW13 Channel 32', 32, 1600)
#list_bessel_fit(path_artdaq, 10307, 'Bessel Fit FWHM Values Run 10307 Crate WE13', 32,64, 1600)
# Out:
# [ 1.11455797e+02  2.40130317e+02 -2.13864695e+02  1.44373553e-01
#   6.03786432e+00  1.49401791e-02  6.89545631e+03  4.55243958e+00
#   1.15149787e+01  3.79675943e+00  9.26786069e+01  3.21332230e+00
#  -6.19922510e+01  2.38286187e+00  1.04577386e+01]
# Peak value 1378.8941602851787 1378.9928343949045
# Integral of fit from -100 to 2000  (10029.410792734234, 0.00014758835476232245)
# Peaks [ 70 247 328 406 475 541 606]
# Widths of peak in fit  [77.76552939 33.20769988 40.36272028 34.86070015 33.80110427 32.80517173
#  32.34693727]
# Chi^2:  -1342.3396384905486
